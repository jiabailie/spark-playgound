# %% [markdown]
# # Spark Playground\n\nThis notebook is mounted from the local `spark-playground` project.\n\nThe examples directory contains runnable Python scripts, and you can also explore the same data interactively here.

# %%
from pyspark.sql import SparkSession\nspark = SparkSession.builder.appName('spark-playground-notebook').master('spark://spark-master:7077').getOrCreate()\nemployees = spark.read.json('/home/jovyan/work/data/employees.jsonl')\nemployees.show()
